# %%
from google.colab import drive 
drive.mount('/content/drive', force_remount = True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# Importacion de bibliotecas

import matplotlib.pyplot as plt
from datetime import datetime
import numpy as np
import random
import pandas as pd
import glob
import seaborn as sns
from IPython.display import display

# %% [markdown]
# # **Funciones**

# %%
# Funcion para visualizar el dataframe con todas sus columnas 
def displaydf(dataframe, cols = None, rows = 54):
    with pd.option_context("display.max_columns", cols):
        with pd.option_context("display.max_rows", rows):
            display(dataframe)
    return True

# %%
# Funcion para interpolar los datos
def interpolate(df):
  #Declarar todas las columnas
  #VITAL SIGNS
  HR=df['HR']
  O2Sat=df['O2Sat']
  Temp=df['Temp']
  SBP=df['SBP']
  MAP=df['MAP']
  DBP=df['DBP']
  Resp=df['Resp']
  EtCO2=df['EtCO2']
  #LABORATORY VALUES
  BaseExcess=df['BaseExcess']
  HCO3=df['HCO3']
  FiO2=df['FiO2']
  pH=df['pH']
  PaCO2=df['PaCO2']
  SaO2=df['SaO2']
  AST=df['AST']
  BUN=df['BUN']
  Alkalinephos=df['Alkalinephos']
  Calcium=df['Calcium']
  Chloride=df['Chloride']
  Creatinine=df['Creatinine']
  Bilirubin_direct=df['Bilirubin_direct']
  Glucose=df['Glucose']
  Lactate=df['Lactate']
  Magnesium=df['Magnesium']
  Phosphate=df['Phosphate']
  Potassium=df['Potassium']
  Bilirubin_total=df['Bilirubin_total']
  TroponinI=df['TroponinI']
  Hct=df['Hct']
  Hgb=df['Hgb']
  PTT=df['PTT']
  WBC=df['WBC']
  Fibrinogen=df['Fibrinogen']
  Platelets=df['Platelets']
  #DEMOGRAPHICS
  Age=df['Age']
  Gender=df['Gender']
  Unit1=df['Unit1']
  Unit2=df['Unit2']
  HospAdmTime=df['HospAdmTime']
  ICULOS=df['ICULOS']
  #Outcome
  SepsisLabel=df['SepsisLabel']

  #Guardamos nombres de las columnas divididos en tres tipos de variables: signos vitales, valores de lab y datos demográficos
  #VITAL SIGNS
  HR2 = HR.fillna(method='backfill')
  HR3 = HR2.fillna(method='ffill')
  O2Sat2 = O2Sat.fillna(method='backfill')
  O2Sat3 = O2Sat2.fillna(method='ffill')
  Temp2 = Temp.fillna(method='backfill')
  Temp3 = Temp2.fillna(method='ffill')      
  SBP2 = SBP.fillna(method='backfill')
  SBP3 = SBP2.fillna(method='ffill')
  MAP2 = MAP.fillna(method='backfill')
  MAP3 = MAP2.fillna(method='ffill')
  DBP2 = DBP.fillna(method='backfill')
  DBP3 = DBP2.fillna(method='ffill')
  Resp2 = Resp.fillna(method='backfill')
  Resp3 = Resp2.fillna(method='ffill')
  EtCO2_2 = EtCO2.fillna(method='backfill')
  EtCO2_3 = EtCO2_2.fillna(method='ffill')
  #LABORATORY VALUES
  BaseExcess2 = BaseExcess.interpolate(method='linear')
  BaseExcess3 = BaseExcess2.interpolate(method='linear',limit_direction='backward')
  HCO3_2 = HCO3.interpolate(method='linear')
  HCO3_3 = HCO3_2.interpolate(method='linear',limit_direction='backward')
  FiO2_2 = FiO2.interpolate(method='linear')
  FiO2_3 = FiO2_2.interpolate(method='linear',limit_direction='backward')
  pH2 = pH.interpolate(method='linear')
  pH3 = pH2.interpolate(method='linear',limit_direction='backward')
  PaCO2_2 = PaCO2.interpolate(method='linear')
  PaCO2_3 = PaCO2_2.interpolate(method='linear',limit_direction='backward')
  SaO2_2 = SaO2.interpolate(method='linear')
  SaO2_3 = SaO2_2.interpolate(method='linear',limit_direction='backward')
  AST2 = AST.interpolate(method='linear')
  AST3 = AST2.interpolate(method='linear',limit_direction='backward')
  BUN2 = BUN.interpolate(method='linear')
  BUN3 = BUN2.interpolate(method='linear',limit_direction='backward')
  Alkalinephos2 = Alkalinephos.interpolate(method='linear')
  Alkalinephos3 = Alkalinephos2.interpolate(method='linear',limit_direction='backward')
  Calcium2 = Calcium.interpolate(method='linear')
  Calcium3 = Calcium2.interpolate(method='linear',limit_direction='backward')
  Chloride2 = Chloride.interpolate(method='linear')
  Chloride3 = Chloride2.interpolate(method='linear',limit_direction='backward')
  Creatinine2 = Creatinine.interpolate(method='linear')
  Creatinine3 = Creatinine2.interpolate(method='linear',limit_direction='backward')
  Bilirubin_direct2 = Bilirubin_direct.interpolate(method='linear')
  Bilirubin_direct3 = Bilirubin_direct2.interpolate(method='linear',limit_direction='backward')
  Glucose2 = Glucose.interpolate(method='linear')
  Glucose3 = Glucose2.interpolate(method='linear',limit_direction='backward')
  Lactate2 = Lactate.interpolate(method='linear')
  Lactate3 = Lactate2.interpolate(method='linear',limit_direction='backward')
  Magnesium2 = Magnesium.interpolate(method='linear')
  Magnesium3 = Magnesium2.interpolate(method='linear',limit_direction='backward')
  Phosphate2 = Phosphate.interpolate(method='linear')
  Phosphate3 = Phosphate2.interpolate(method='linear',limit_direction='backward')
  Potassium2 = Potassium.interpolate(method='linear')
  Potassium3 = Potassium2.interpolate(method='linear',limit_direction='backward')
  Bilirubin_total2 = Bilirubin_total.interpolate(method='linear')
  Bilirubin_total3 = Bilirubin_total2.interpolate(method='linear',limit_direction='backward')
  TroponinI2 = TroponinI.interpolate(method='linear')
  TroponinI3 = TroponinI2.interpolate(method='linear',limit_direction='backward')
  Hct2 = Hct.interpolate(method='linear')
  Hct3 = Hct2.interpolate(method='linear',limit_direction='backward')
  Hgb2 = Hgb.interpolate(method='linear')
  Hgb3 = Hgb2.interpolate(method='linear',limit_direction='backward')
  PTT2 = PTT.interpolate(method='linear')
  PTT3 = PTT2.interpolate(method='linear',limit_direction='backward')
  WBC2 = WBC.interpolate(method='linear')
  WBC3 = WBC2.interpolate(method='linear',limit_direction='backward')
  Fibrinogen2 = Fibrinogen.interpolate(method='linear')
  Fibrinogen3 = Fibrinogen2.interpolate(method='linear',limit_direction='backward')
  Platelets2 = Platelets.interpolate(method='linear')
  Platelets3 = Platelets2.interpolate(method='linear',limit_direction='backward')

# Recopilar todas las variables una vez interpoladas
  matrix = pd.DataFrame({"HR" : HR3, "O2Sat": O2Sat3, "Temp": Temp3, "SBP":SBP3, "MAP":MAP3, "DBP":DBP3, "Resp":Resp3, "EtCO2":EtCO2_3, "BaseExcess":BaseExcess3, "HCO3":HCO3_3, "FiO2":FiO2_3, "pH":pH3, "PaCO2":PaCO2_3, "SaO2":SaO2_3, 
                      "AST":AST3, "BUN":BUN3, "Alkalinephos":Alkalinephos3, "Calcium":Calcium3, "Chloride":Chloride3, "Creatinine":Creatinine3, "Bilirubin_direct":Bilirubin_direct3, "Glucose":Glucose3, "Lactate":Lactate3, 
                      "Magnesium":Magnesium3, "Phosphate":Phosphate3, "Potassium":Potassium3, "Bilirubin_total":Bilirubin_total3, "TroponinI":TroponinI3, "Hct":Hct3, "Hgb":Hgb3, "PTT":PTT3, "WBC":WBC3, "Fibrinogen":Fibrinogen3,
                      "Platelets":Platelets3, "Age": Age, "Gender":Gender, "Unit1":Unit1, "Unit2":Unit2, "HospAdmTime":HospAdmTime, "ICULOS":ICULOS, "SepsisLabel":SepsisLabel},columns=["HR", "O2Sat", "Temp", "SBP", "MAP","DBP", "Resp", "EtCO2", "BaseExcess", "HCO3", "FiO2", "pH", "PaCO2", "SaO2", 
                      "AST", "BUN", "Alkalinephos", "Calcium", "Chloride", "Creatinine", "Bilirubin_direct", "Glucose", "Lactate", 
                      "Magnesium", "Phosphate", "Potassium", "Bilirubin_total", "TroponinI", "Hct", "Hgb", "PTT", "WBC", "Fibrinogen",
                      "Platelets", "Age", "Gender", "Unit1", "Unit2", "HospAdmTime", "ICULOS", "SepsisLabel"])
  
  return matrix

# %% [markdown]
# # **Representación de datos de un paciente prueba**

# %%
# Cargamos datos de un paciente con sepsis para tomarlo como prueba
paciente_prueba = pd.read_csv("/content/drive/My Drive/Colab Notebooks/training_setA/p000011.psv",sep='|')

# %% [markdown]
# ## Visualización de datos en bruto

# %%
# Mostramos variables del paciente prueba
displaydf(paciente_prueba)
# Out:
#        HR  O2Sat   Temp    SBP    MAP   DBP  Resp  EtCO2  BaseExcess  HCO3  \
# 0    81.0  100.0    NaN    NaN    NaN   NaN  12.5    NaN         0.0  22.5
# 1    82.0  100.0  38.00  136.5   90.0  71.0  12.0    NaN         NaN   NaN
# 2    81.0  100.0  38.11  114.0   87.0  61.0  12.0    NaN         NaN   NaN
# 3    82.0  100.0    NaN  114.0   79.0  62.0  12.0    NaN         NaN  24.0
# 4    84.0  100.0    NaN  117.0   79.0  61.0  16.0    NaN         NaN   NaN
# 5    84.0  100.0    NaN  103.0   73.5  58.0  20.0    NaN         NaN   NaN
# 6    85.0  100.0  38.17  123.0   72.0  66.0  18.0    NaN         NaN   NaN
# 7    85.0  100.0    NaN  143.0   96.0  72.0  14.0    NaN         NaN   NaN
# 8     NaN    NaN    NaN    NaN    NaN   NaN   NaN    NaN         NaN   NaN
# 9    79.0  100.0    NaN  146.0   93.0  63.0  12.0    NaN         NaN   NaN
# 10   80.0  100.0  37.44  137.0   91.0  66.0  14.5    NaN         NaN  23.0
# ...

# %%
#Guardamos nombres de las variables (columnas) divididas en tres tipos: signos vitales, valores de laboratorio y datos demograficos

#VITALSIGNS
HR=paciente_prueba['HR']
O2Sat=paciente_prueba['O2Sat']
Temp=paciente_prueba['Temp']
SBP=paciente_prueba['SBP']
MAP=paciente_prueba['MAP']
DBP=paciente_prueba['DBP']
Resp=paciente_prueba['Resp']
EtCO2=paciente_prueba['EtCO2']
#LABORATORYVALUES
BaseExcess=paciente_prueba['BaseExcess']
HCO3=paciente_prueba['HCO3']
FiO2=paciente_prueba['FiO2']
pH=paciente_prueba['pH']
PaCO2=paciente_prueba['PaCO2']
SaO2=paciente_prueba['SaO2']
AST=paciente_prueba['AST']
BUN=paciente_prueba['BUN']
Alkalinephos=paciente_prueba['Alkalinephos']
Calcium=paciente_prueba['Calcium']
Chloride=paciente_prueba['Chloride']
Creatinine=paciente_prueba['Creatinine']
Bilirubin_direct=paciente_prueba['Bilirubin_direct']
Glucose=paciente_prueba['Glucose']
Lactate=paciente_prueba['Lactate']
Magnesium=paciente_prueba['Magnesium']
Phosphate=paciente_prueba['Phosphate']
Potassium=paciente_prueba['Potassium']
Bilirubin_total=paciente_prueba['Bilirubin_total']
TroponinI=paciente_prueba['TroponinI']
Hct=paciente_prueba['Hct']
Hgb=paciente_prueba['Hgb']
PTT=paciente_prueba['PTT']
WBC=paciente_prueba['WBC']
Fibrinogen=paciente_prueba['Fibrinogen']
Platelets=paciente_prueba['Platelets']
#DEMOGRAPHICS
Age=paciente_prueba['Age']
Gender=paciente_prueba['Gender']
Unit1=paciente_prueba['Unit1']
Unit2=paciente_prueba['Unit2']
HospAdmTime=paciente_prueba['HospAdmTime']
ICULOS=paciente_prueba['ICULOS']
#Outcome
SepsisLabel=paciente_prueba['SepsisLabel']

# %% [markdown]
# ### Representación de las variables con missing data a lo largo del tiempo

# %%
t = np.arange(0,len(paciente_prueba)) #Creamos el eje x de tiempo con su periodo correspondiente

plt.figure()
plt.plot(t,HR,'o')
plt.plot(t,HR,linewidth=0.5)
plt.xlabel('Time [hora]')
plt.ylabel('HR')
plt.figure()
plt.plot(t,O2Sat,'o')
plt.plot(t,O2Sat,linewidth=0.5)
plt.xlabel('Time [hora]')
plt.ylabel('O2Sat')
plt.figure()
plt.plot(t,Temp,'o')
plt.plot(t,Temp,linewidth=0.5)
plt.xlabel('Time [hora]')
plt.ylabel('Temp')
plt.figure()
plt.plot(t,SBP,'o')
plt.plot(t,SBP,linewidth=0.5)
plt.xlabel('Time [hora]')
plt.ylabel('SBP')
plt.figure()
plt.plot(t,MAP,'o')
plt.plot(t,MAP,linewidth=0.5)
plt.xlabel('Time [hora]')
plt.ylabel('MAP')
plt.figure()
plt.plot(t,DBP,'o')
plt.plot(t,DBP,linewidth=0.5)
plt.xlabel('Time [hora]')
plt.ylabel('DBP')
plt.figure()
plt.plot(t,Resp,'o')
plt.plot(t,Resp,linewidth=0.5)
plt.xlabel('Time [hora]')
plt.ylabel('Resp')
plt.figure()
plt.plot(t,EtCO2,'o')
plt.plot(t,EtCO2,linewidth=0.5)
plt.xlabel('Time [hora]')
plt.ylabel('EtCO2')
plt.figure()
plt.plot(t,BaseExcess,'o')
plt.plot(t,BaseExcess,linewidth=0.5)
plt.xlabel('Time [hora]')
plt.ylabel('BaseExcess')
plt.figure()
plt.plot(t,HCO3,'o')
plt.plot(t,HCO3,linewidth=0.5)
plt.xlabel('Time [hora]')
plt.ylabel('HCO3')
plt.figure()
plt.plot(t,FiO2,'o')
plt.plot(t,FiO2,linewidth=0.5)
plt.xlabel('Time [hora]')
plt.ylabel('FiO2')
plt.figure()
plt.plot(t,pH,'o')
plt.plot(t,pH,linewidth=0.5)
plt.xlabel('Time [hora]')
plt.ylabel('pH')
plt.figure()
plt.plot(t,PaCO2,'o')
plt.plot(t,PaCO2,linewidth=0.5)
plt.xlabel('Time [hora]')
plt.ylabel('PaCO2')
plt.figure()
plt.plot(t,SaO2,'o')
plt.plot(t,SaO2,linewidth=0.5)
plt.xlabel('Time [hora]')
plt.ylabel('SaO2')
plt.figure()
plt.plot(t,AST,'o')
plt.plot(t,AST,linewidth=0.5)
plt.xlabel('Time [hora]')
plt.ylabel('AST')
plt.figure()
plt.plot(t,BUN,'o')
plt.plot(t,BUN,linewidth=0.5)
plt.xlabel('Time [hora]')
plt.ylabel('BUN')
plt.figure()
plt.plot(t,Alkalinephos,'o')
plt.plot(t,Alkalinephos,linewidth=0.5)
plt.xlabel('Time [hora]')
plt.ylabel('Alkalinephos')
plt.figure()
plt.plot(t,Calcium,'o')
plt.plot(t,Calcium,linewidth=0.5)
plt.xlabel('Time [hora]')
plt.ylabel('Calcium')
plt.figure()
plt.plot(t,Chloride,'o')
plt.plot(t,Chloride,linewidth=0.5)
plt.xlabel('Time [hora]')
plt.ylabel('Chloride')
plt.figure()
plt.plot(t,Creatinine,'o')
plt.plot(t,Creatinine,linewidth=0.5)
plt.xlabel('Time [hora]')
plt.ylabel('Creatinine')
plt.figure()
plt.plot(t,Bilirubin_direct,'o')
plt.plot(t,Bilirubin_direct,linewidth=0.5)
plt.xlabel('Time [hora]')
plt.ylabel('Bilirubin_direct')
plt.figure()
plt.plot(t,Glucose,'o')
plt.plot(t,Glucose,linewidth=0.5)
plt.xlabel('Time [hora]')
plt.ylabel('Glucose')
plt.figure()
plt.plot(t,Lactate,'o')
plt.plot(t,Lactate,linewidth=0.5)
plt.xlabel('Time [hora]')
plt.ylabel('Lactate')
plt.figure()
plt.plot(t,Magnesium,'o')
plt.plot(t,Magnesium,linewidth=0.5)
plt.xlabel('Time [hora]')
plt.ylabel('Magnesium')
plt.figure()
plt.plot(t,Phosphate,'o')
plt.plot(t,Phosphate,linewidth=0.5)
plt.xlabel('Time [hora]')
plt.ylabel('Phosphate')
plt.figure()
plt.plot(t,Potassium,'o')
plt.plot(t,Potassium,linewidth=0.5)
plt.xlabel('Time [hora]')
plt.ylabel('Potassium')
plt.figure()
plt.plot(t,Bilirubin_total,'o')
plt.plot(t,Bilirubin_total,linewidth=0.5)
plt.xlabel('Time [hora]')
plt.ylabel('Bilirubin_total')
plt.figure()
plt.plot(t,TroponinI,'o')
plt.plot(t,TroponinI,linewidth=0.5)
plt.xlabel('Time [hora]')
plt.ylabel('TroponinI')
plt.figure()
plt.plot(t,Hct,'o')
plt.plot(t,Hct,linewidth=0.5)
plt.xlabel('Time [hora]')
plt.ylabel('Hct')
plt.figure()
plt.plot(t,Hgb,'o')
plt.plot(t,Hgb,linewidth=0.5)
plt.xlabel('Time [hora]')
plt.ylabel('Hgb')
plt.figure()
plt.plot(t,PTT,'o')
plt.plot(t,PTT,linewidth=0.5)
plt.xlabel('Time [hora]')
plt.ylabel('PTT')
plt.figure()
plt.plot(t,WBC,'o')
plt.plot(t,WBC,linewidth=0.5)
plt.xlabel('Time [hora]')
plt.ylabel('WBC')
plt.figure()
plt.plot(t,Fibrinogen,'o')
plt.plot(t,Fibrinogen,linewidth=0.5)
plt.xlabel('Time [hora]')
plt.ylabel('Fibrinogen')
plt.figure()
plt.plot(t,Platelets,'o')
plt.plot(t,Platelets,linewidth=0.5)
plt.xlabel('Time [hora]')
plt.ylabel('Platelets')
plt.figure()
plt.plot(t,ICULOS,'o')
plt.plot(t,ICULOS,linewidth=0.5)
plt.xlabel('Time [hora]')
plt.ylabel('ICULOS')
plt.figure()
plt.plot(t,SepsisLabel,'o')
plt.plot(t,SepsisLabel,linewidth=0.5)
plt.xlabel('Time [hora]')
plt.ylabel('SepsisLabel')
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.py:522: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# Text(0,0.5,'SepsisLabel')

# %% [markdown]
# ### Histogramas

# %%
#Visualizamos todos los histogramas a la vez
paciente_prueba.hist(figsize = (20,20), bins= 50, xlabelsize=8, ylabelsize=8)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f652f560f50>,
# ...
#       dtype=object)

# %%
HR.plot.hist(bins=6, color='blue', edgecolor = 'black',  linewidth=1)
plt.xlabel('HR')
plt.ylabel('Frecuencia')
plt.xlim(60,150)
plt.figure()
O2Sat.plot.hist(bins=6, color='blue', edgecolor = 'black',  linewidth=1)
plt.xlabel('O2Sat')
plt.ylabel('Frecuencia')
plt.xlim(60,120)
plt.figure()
Temp.plot.hist(bins=13, color='blue', edgecolor = 'black',  linewidth=1)
plt.xlabel('Temp')
plt.ylabel('Frecuencia')
plt.xlim(35,40)
plt.figure()
SBP.plot.hist(bins=16, color='blue', edgecolor = 'black',  linewidth=1)
plt.xlabel('SBP')
plt.ylabel('Frecuencia')
plt.xlim(70,200)
plt.figure()
MAP.plot.hist(bins=16, color='blue', edgecolor = 'black',  linewidth=1)
plt.xlabel('MAP')
plt.ylabel('Frecuencia')
plt.xlim(40,160)
plt.figure()
DBP.plot.hist(bins=9, color='blue', edgecolor = 'black',  linewidth=1)
plt.xlabel('DBP')
plt.ylabel('Frecuencia')
plt.xlim(0,100)
plt.figure()
Resp.plot.hist(bins=30, color='blue', edgecolor = 'black',  linewidth=1)
plt.xlabel('Resp')
plt.ylabel('Frecuencia')
plt.xlim(15,35)
plt.figure()
EtCO2.plot.hist(bins=20, color='blue', edgecolor = 'black',  linewidth=1)
plt.xlabel('EtCO2')
plt.ylabel('Frecuencia')
plt.xlim(0,170)
plt.figure()
BaseExcess.plot.hist(bins=10, color='blue', edgecolor = 'black',  linewidth=1)
plt.xlabel('BaseExcess')
plt.ylabel('Frecuencia')
plt.xlim(15,30)
plt.figure()
HCO3.plot.hist(bins=10, color='blue', edgecolor = 'black',  linewidth=1)
plt.xlabel('HCO3')
plt.ylabel('Frecuencia')
plt.xlim(40,50)
plt.figure()
FiO2.plot.hist(bins=100, color='blue', edgecolor = 'black',  linewidth=1)
plt.xlabel('FiO2')
plt.ylabel('Frecuencia')
plt.xlim(0,20)
plt.figure()
pH.plot.hist(bins=500, color='blue', edgecolor = 'black',  linewidth=1)
plt.xlabel('pH')
plt.ylabel('Frecuencia')
plt.xlim(0,1)
plt.figure()
PaCO2.plot.hist(bins=100, color='blue', edgecolor = 'black',  linewidth=1)
plt.xlabel('PaCO2')
plt.ylabel('Frecuencia')
plt.xlim(0,1)
plt.figure()
SaO2.plot.hist(bins=500, color='blue', edgecolor = 'black',  linewidth=1)
plt.xlabel('SaO2')
plt.ylabel('Frecuencia')
plt.xlim(0,0.1)
plt.figure()
AST.plot.hist(bins=10, color='blue', edgecolor = 'black',  linewidth=1)
plt.xlabel('AST')
plt.ylabel('Frecuencia')
plt.xlim(0,1)
plt.figure()
BUN.plot.hist(bins=10, color='blue', edgecolor = 'black',  linewidth=1)
plt.xlabel('BUN')
plt.ylabel('Frecuencia')
plt.xlim(0,1)
plt.figure()
Alkalinephos.plot.hist(bins=20, color='blue', edgecolor = 'black',  linewidth=1)
plt.xlabel('Alkalinephos')
plt.ylabel('Frecuencia')
plt.figure()
Calcium.plot.hist(bins=20, color='blue', edgecolor = 'black',  linewidth=1)
plt.xlabel('Calcium')
plt.ylabel('Frecuencia')
plt.figure()
Creatinine.plot.hist(bins=20, color='blue', edgecolor = 'black',  linewidth=1)
plt.xlabel('Creatinine')
plt.ylabel('Frecuencia')
plt.figure()
Bilirubin_direct.plot.hist(bins=20, color='blue', edgecolor = 'black',  linewidth=1)
plt.xlabel('Bilirubin_direct')
plt.ylabel('Frecuencia')
plt.figure()
Glucose.plot.hist(bins=20, color='blue', edgecolor = 'black',  linewidth=1)
plt.xlabel('Glucose')
plt.ylabel('Frecuencia')
plt.figure()
Lactate.plot.hist(bins=20, color='blue', edgecolor = 'black',  linewidth=1)
plt.xlabel('Lactate')
plt.ylabel('Frecuencia')
plt.figure()
Magnesium.plot.hist(bins=20, color='blue', edgecolor = 'black',  linewidth=1)
plt.xlabel('Magnesium')
plt.ylabel('Frecuencia')
plt.figure()
Phosphate.plot.hist(bins=20, color='blue', edgecolor = 'black',  linewidth=1)
plt.xlabel('Phosphate')
plt.ylabel('Frecuencia')
plt.figure()
Potassium.plot.hist(bins=20, color='blue', edgecolor = 'black',  linewidth=1)
plt.xlabel('Potassium')
plt.ylabel('Frecuencia')
plt.figure()
Bilirubin_total.plot.hist(bins=20, color='blue', edgecolor = 'black',  linewidth=1)
plt.xlabel('Bilirubin_total')
plt.ylabel('Frecuencia')
plt.figure()
TroponinI.plot.hist(bins=20, color='blue', edgecolor = 'black',  linewidth=1)
plt.xlabel('TroponinI')
plt.ylabel('Frecuencia')
plt.figure()
Hct.plot.hist(bins=20, color='blue', edgecolor = 'black',  linewidth=1)
plt.xlabel('Hct')
plt.ylabel('Frecuencia')
plt.figure()
Hgb.plot.hist(bins=20, color='blue', edgecolor = 'black',  linewidth=1)
plt.xlabel('Hgb')
plt.ylabel('Frecuencia')
plt.figure()
PTT.plot.hist(bins=20, color='blue', edgecolor = 'black',  linewidth=1)
plt.xlabel('PTT')
plt.ylabel('Frecuencia')
plt.figure()
WBC.plot.hist(bins=20, color='blue', edgecolor = 'black',  linewidth=1)
plt.xlabel('WBC')
plt.ylabel('Frecuencia')
plt.figure()
Fibrinogen.plot.hist(bins=20, color='blue', edgecolor = 'black',  linewidth=1)
plt.xlabel('Fibrinogen')
plt.ylabel('Frecuencia')
plt.figure()
Platelets.plot.hist(bins=20, color='blue', edgecolor = 'black',  linewidth=1)
plt.xlabel('Platelets')
plt.ylabel('Frecuencia')
plt.figure()
Age.plot.hist(bins=20, color='blue', edgecolor = 'black',  linewidth=1)
plt.xlabel('Age')
plt.ylabel('Frecuencia')
plt.figure()
Gender.plot.hist(bins=10, color='blue', edgecolor = 'black',  linewidth=1)
plt.xlabel('Gender')
plt.ylabel('Frecuencia')
plt.xlim(0,1)
plt.figure()
Unit1.plot.hist(bins=20, color='blue', edgecolor = 'black',  linewidth=1)
plt.xlabel('Unit1')
plt.ylabel('Frecuencia')
plt.figure()
Unit2.plot.hist(bins=20, color='blue', edgecolor = 'black',  linewidth=1)
plt.xlabel('Unit2')
plt.ylabel('Frecuencia')
plt.figure()
HospAdmTime.plot.hist(bins=20, color='blue', edgecolor = 'black',  linewidth=1)
plt.xlabel('HospAdmTime')
plt.ylabel('Frecuencia')
plt.figure()
ICULOS.plot.hist(bins=10, color='blue', edgecolor = 'black',  linewidth=1)
plt.xlabel('ICULOS')
plt.ylabel('Frecuencia')
plt.figure()
SepsisLabel.value_counts().plot.bar(color='blue')
plt.xlabel('SepsisLabel')
plt.ylabel('Frecuencia')
plt.figure()
SepsisLabel.plot.hist(bins=10, color='blue', edgecolor = 'black',  linewidth=1)
plt.xlabel('SepsisLabel')
plt.ylabel('Frecuencia')
plt.figure()

# %% [markdown]
# ### Diagrama de cajas y bigotes

# %%
paciente_prueba.boxplot(grid=False, rot=60,figsize= (20,9))

# %%
boxplot = paciente_prueba.boxplot(column=['HR'])
plt.figure()
boxplot = paciente_prueba.boxplot(column=['O2Sat'])
plt.figure()
boxplot = paciente_prueba.boxplot(column=['Temp'])
plt.figure()
boxplot = paciente_prueba.boxplot(column=['SBP'])
plt.figure()
boxplot = paciente_prueba.boxplot(column=['HR'])
plt.figure()
boxplot = paciente_prueba.boxplot(column=['MAP'])
plt.figure()
boxplot = paciente_prueba.boxplot(column=['DBP'])
plt.figure()
boxplot = paciente_prueba.boxplot(column=['Resp'])
plt.figure()
boxplot = paciente_prueba.boxplot(column=['EtCO2'])
plt.figure()
boxplot = paciente_prueba.boxplot(column=['BaseExcess'])
plt.figure()
boxplot = paciente_prueba.boxplot(column=['HCO3'])
plt.figure()
boxplot = paciente_prueba.boxplot(column=['FiO2'])
plt.figure()
boxplot = paciente_prueba.boxplot(column=['pH'])
plt.figure()
boxplot = paciente_prueba.boxplot(column=['PaCO2'])
plt.figure()
boxplot = paciente_prueba.boxplot(column=['SaO2'])
plt.figure()
boxplot = paciente_prueba.boxplot(column=['AST'])
plt.figure()
boxplot = paciente_prueba.boxplot(column=['BUN'])
plt.figure()
boxplot = paciente_prueba.boxplot(column=['Alkalinephos'])
plt.figure()
boxplot = paciente_prueba.boxplot(column=['Calcium'])
plt.figure()
boxplot = paciente_prueba.boxplot(column=['Chloride'])
plt.figure()
boxplot = paciente_prueba.boxplot(column=['Creatinine'])
plt.figure()
boxplot = paciente_prueba.boxplot(column=['Bilirubin_direct'])
plt.figure()
boxplot = paciente_prueba.boxplot(column=['Glucose'])
plt.figure()
boxplot = paciente_prueba.boxplot(column=['Lactate'])
plt.figure()
boxplot = paciente_prueba.boxplot(column=['Magnesium'])
plt.figure()
boxplot = paciente_prueba.boxplot(column=['Phosphate'])
plt.figure()
boxplot = paciente_prueba.boxplot(column=['Potassium'])
plt.figure()
boxplot = paciente_prueba.boxplot(column=['Bilirubin_total'])
plt.figure()
boxplot = paciente_prueba.boxplot(column=['TroponinI'])
plt.figure()
boxplot = paciente_prueba.boxplot(column=['Hct'])
plt.figure()
boxplot = paciente_prueba.boxplot(column=['SaO2'])
plt.figure()
boxplot = paciente_prueba.boxplot(column=['Hgb'])
plt.figure()
boxplot = paciente_prueba.boxplot(column=['PTT'])
plt.figure()
boxplot = paciente_prueba.boxplot(column=['WBC'])
plt.figure()
boxplot = paciente_prueba.boxplot(column=['Fibrinogen'])
plt.figure()
boxplot = paciente_prueba.boxplot(column=['Platelets'])
plt.figure()
boxplot = paciente_prueba.boxplot(column=['Age'])
plt.figure()
boxplot = paciente_prueba.boxplot(column=['Gender'])
plt.figure()
boxplot = paciente_prueba.boxplot(column=['HospAdmTime'])
plt.figure()
boxplot = paciente_prueba.boxplot(column=['SepsisLabel'])
plt.figure()

# %% [markdown]
# ### Mapa de correlación

# %%
corr=paciente_prueba.corr()
plt.figure(figsize=(20,20))
sns.heatmap(corr, annot= True, xticklabels=corr.columns.values, yticklabels=corr.columns.values)

# %% [markdown]
# ## Interpolación y visualización de los datos

# %% [markdown]
# ### Interpolación de los datos con la función y su visualización

# %%
# Interpolamos las variables con la funcion y visualizamos
paciente_prueba_interpolated = interpolate(paciente_prueba)
displaydf(paciente_prueba_interpolated)
# Out:
#        HR  O2Sat   Temp    SBP    MAP   DBP  Resp  EtCO2  BaseExcess  \
# 0    81.0  100.0  38.00  136.5   90.0  71.0  12.5    NaN    0.000000
# 1    82.0  100.0  38.00  136.5   90.0  71.0  12.0    NaN    0.000000
# 2    81.0  100.0  38.11  114.0   87.0  61.0  12.0    NaN    0.000000
# 3    82.0  100.0  38.17  114.0   79.0  62.0  12.0    NaN    0.000000
# 4    84.0  100.0  38.17  117.0   79.0  61.0  16.0    NaN    0.000000
# 5    84.0  100.0  38.17  103.0   73.5  58.0  20.0    NaN    0.000000
# 6    85.0  100.0  38.17  123.0   72.0  66.0  18.0    NaN    0.000000
# 7    85.0  100.0  37.44  143.0   96.0  72.0  14.0    NaN    0.000000
# 8    79.0  100.0  37.44  146.0   93.0  63.0  12.0    NaN    0.000000
# 9    79.0  100.0  37.44  146.0   93.0  63.0  12.0    NaN    0.000000
# 10   80.0  100.0  37.44  137.0   91.0  66.0  14.5    NaN    0.000000
# 11   81.0  100.0  37.17  146.0   97.0  69.0  22.0    NaN    0.000000
# 12   85.0  100.0  37.17  107.0   74.0  54.0  15.0    NaN    0.111111
# ...

# %%
# Renombramos las variables una vez interpoladas

#VITAL SIGNS
HR3=paciente_prueba_interpolated['HR']
O2Sat3=paciente_prueba_interpolated['O2Sat']
Temp3=paciente_prueba_interpolated['Temp']
SBP3=paciente_prueba_interpolated['SBP']
MAP3=paciente_prueba_interpolated['MAP']
DBP3=paciente_prueba_interpolated['DBP']
Resp3=paciente_prueba_interpolated['Resp']
EtCO2_3=paciente_prueba_interpolated['EtCO2']
#LABORATORY VALUES
BaseExcess3=paciente_prueba_interpolated['BaseExcess']
HCO3_3=paciente_prueba_interpolated['HCO3']
FiO2_3=paciente_prueba_interpolated['FiO2']
pH3=paciente_prueba_interpolated['pH']
PaCO2_3=paciente_prueba_interpolated['PaCO2']
SaO2_3=paciente_prueba_interpolated['SaO2']
AST3=paciente_prueba_interpolated['AST']
BUN3=paciente_prueba_interpolated['BUN']
Alkalinephos3=paciente_prueba_interpolated['Alkalinephos']
Calcium3=paciente_prueba_interpolated['Calcium']
Chloride3=paciente_prueba_interpolated['Chloride']
Creatinine3=paciente_prueba_interpolated['Creatinine']
Bilirubin_direct3=paciente_prueba_interpolated['Bilirubin_direct']
Glucose3=paciente_prueba_interpolated['Glucose']
Lactate3=paciente_prueba_interpolated['Lactate']
Magnesium3=paciente_prueba_interpolated['Magnesium']
Phosphate3=paciente_prueba_interpolated['Phosphate']
Potassium3=paciente_prueba_interpolated['Potassium']
Bilirubin_total3=paciente_prueba_interpolated['Bilirubin_total']
TroponinI3=paciente_prueba_interpolated['TroponinI']
Hct3=paciente_prueba_interpolated['Hct']
Hgb3=paciente_prueba_interpolated['Hgb']
PTT3=paciente_prueba_interpolated['PTT']
WBC3=paciente_prueba_interpolated['WBC']
Fibrinogen3=paciente_prueba_interpolated['Fibrinogen']
Platelets3=paciente_prueba_interpolated['Platelets']

# %% [markdown]
# ### Representación de las variables con datos interpolados a lo largo del tiempo

# %%
t = np.arange(0,len(paciente_prueba_interpolated)) #Creamos el eje x de tiempo con su periodo correspondiente
plt.figure()
plt.plot(t,HR3,'o')
plt.plot(t,HR3)
plt.xlabel('Time [hora]')
plt.ylabel('HR')
plt.figure()
plt.plot(t,O2Sat3,'o')
plt.plot(t,O2Sat3)
plt.xlabel('Time [hora]')
plt.ylabel('O2Sat')
plt.figure()
plt.plot(t,Temp3,'o')
plt.plot(t,Temp3)
plt.xlabel('Time [hora]')
plt.ylabel('Temp')
plt.figure()
plt.plot(t,SBP3,'o')
plt.plot(t,SBP3)
plt.xlabel('Time [hora]')
plt.ylabel('SBP')
plt.figure()
plt.plot(t,MAP3,'o')
plt.plot(t,MAP3)
plt.xlabel('Time [hora]')
plt.ylabel('MAP')
plt.figure()
plt.plot(t,DBP3,'o')
plt.plot(t,DBP3)
plt.xlabel('Time [hora]')
plt.ylabel('DBP')
plt.figure()
plt.plot(t,Resp3,'o')
plt.plot(t,Resp3)
plt.xlabel('Time [hora]')
plt.ylabel('Resp')
plt.figure()
plt.plot(t,EtCO2_3,'o')
plt.plot(t,EtCO2_3)
plt.xlabel('Time [hora]')
plt.ylabel('EtCO2')
plt.figure()
plt.plot(t,BaseExcess3,'o')
plt.plot(t,BaseExcess3)
plt.xlabel('Time [hora]')
plt.ylabel('BaseExcess')
plt.figure()
plt.plot(t,HCO3_3,'o')
plt.plot(t,HCO3_3)
plt.xlabel('Time [hora]')
plt.xlim(0,300)
plt.ylabel('HCO3')
plt.figure()
plt.plot(t,FiO2_3,'o')
plt.plot(t,FiO2_3)
plt.xlabel('Time [hora]')
plt.ylabel('FiO2')
plt.figure()
plt.plot(t,pH3,'o')
plt.plot(t,pH3)
plt.xlabel('Time [hora]')
plt.ylabel('pH')
plt.figure()
plt.plot(t,PaCO2_3,'o')
plt.plot(t,PaCO2_3)
plt.xlabel('Time [hora]')
plt.ylabel('PaCO2')
plt.figure()
plt.plot(t,SaO2_3,'o')
plt.plot(t,SaO2_3)
plt.xlabel('Time [hora]')
plt.ylabel('SaCO2')
plt.figure()
plt.plot(t,AST3,'o')
plt.plot(t,AST3)
plt.xlabel('Time [hora]')
plt.ylabel('AST')
plt.figure()
plt.plot(t,BUN3,'o')
plt.plot(t,BUN3)
plt.xlabel('Time [hora]')
plt.ylabel('BUN')
plt.figure()
plt.plot(t,Alkalinephos3,'o')
plt.plot(t,Alkalinephos3)
plt.xlabel('Time [hora]')
plt.ylabel('Alkalinephos')
plt.figure()
plt.plot(t,Calcium3,'o')
plt.plot(t,Calcium3)
plt.xlabel('Time [hora]')
plt.ylabel('Calcium')
plt.figure()
plt.plot(t,Chloride3,'o')
plt.plot(t,Chloride3)
plt.xlabel('Time [hora]')
plt.ylabel('Chloride')
plt.figure()
plt.plot(t,Creatinine3,'o')
plt.plot(t,Creatinine3)
plt.xlabel('Time [hora]')
plt.ylabel('Creatinine')
plt.figure()
plt.plot(t,Bilirubin_direct3,'o')
plt.plot(t,Bilirubin_direct3)
plt.xlabel('Time [hora]')
plt.ylabel('Bilirubin_direct')
plt.figure()
plt.plot(t,Glucose3,'o')
plt.plot(t,Glucose3)
plt.xlabel('Time [hora]')
plt.ylabel('Glucose')
plt.figure()
plt.plot(t,Lactate3,'o')
plt.plot(t,Lactate3)
plt.xlabel('Time [hora]')
plt.ylabel('Lactate')
plt.figure()
plt.plot(t,Magnesium3,'o')
plt.plot(t,Magnesium3)
plt.xlabel('Time [hora]')
plt.ylabel('Magnesium')
plt.figure()
plt.plot(t,Phosphate3,'o')
plt.plot(t,Phosphate3)
plt.xlabel('Time [hora]')
plt.ylabel('Phosphate')
plt.figure()
plt.plot(t,Potassium3,'o')
plt.plot(t,Potassium3)
plt.xlabel('Time [hora]')
plt.ylabel('Potassium')
plt.figure()
plt.plot(t,Bilirubin_total3,'o')
plt.plot(t,Bilirubin_total3)
plt.xlabel('Time [hora]')
plt.ylabel('Bilirubin_total')
plt.figure()
plt.plot(t,TroponinI3,'o')
plt.plot(t,TroponinI3)
plt.xlabel('Time [hora]')
plt.ylabel('TroponinI')
plt.figure()
plt.plot(t,Hct3,'o')
plt.plot(t,Hct3)
plt.xlabel('Time [hora]')
plt.ylabel('HCT')
plt.figure()
plt.plot(t,Hgb3,'o')
plt.plot(t,Hgb3)
plt.xlabel('Time [hora]')
plt.ylabel('HGB')
plt.figure()
plt.plot(t,PTT3,'o')
plt.plot(t,PTT3)
plt.xlabel('Time [hora]')
plt.ylabel('PTT')
plt.figure()
plt.plot(t,WBC3,'o')
plt.plot(t,WBC3)
plt.xlabel('Time [hora]')
plt.ylabel('WBC')
plt.figure()
plt.plot(t,Fibrinogen3,'o')
plt.plot(t,Fibrinogen3)
plt.xlabel('Time [hora]')
plt.ylabel('Fibrinogen')
plt.figure()
plt.plot(t,Platelets3,'o')
plt.plot(t,Platelets3)
plt.xlabel('Time [hora]')
plt.ylabel('Platelets')
# Out:
# Text(0,0.5,'Platelets')
